# %% [markdown]
# <a href="https://colab.research.google.com/github/kkewat/Big_Mart_Sales_Prediction/blob/main/Train_Clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the required datasets
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the dataset

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
#Viewing the Null Values in the Dataset
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#Viewing the data type of the columns
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# #Filling the null values

# %%
data['Item_Weight'] = data['Item_Weight'].fillna(data['Item_Weight'].mean())

# %%
data['Outlet_Size'] = data['Outlet_Size'].fillna(data['Outlet_Size'].mode()[0])

# %%
#Checking if there is any remaining null values
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#Viewing the Data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ENcoding the Data

# %%
data['Item_Fat_Content'].isna().sum()
# Out:
# 0

# %%
data['Item_Fat_Content'] = data['Item_Fat_Content'].map({'LF':1,'Low Fat':1,'low fat':1,'Low fat':1,'low Fat':1,'lf':1,'regular':2,'Regular':2,'reg':2,'Reg':2})

# %%
data['Item_Fat_Content'].isna().sum()
# Out:
# 0

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 2         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 2         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data['Outlet_Size'] = data['Outlet_Size'].map({'High':1,'Medium':2,'Small':3})
data['Outlet_Location_Type'] = data['Outlet_Location_Type'].map({'Tier 1':1,'Tier 2':2,'Tier 3':3})
data['Outlet_Type'] = data['Outlet_Type'].map({'Grocery Store':1,'Supermarket Type1':2,'Supermarket Type2':3,'Supermarket Type3':4})

# %%
data = pd.get_dummies(data, columns=['Item_Type','Outlet_Identifier'])

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           FDA15         9.30                 1         0.016047  249.8092
# 1           DRC01         5.92                 2         0.019278   48.2692
# 2           FDN15        17.50                 1         0.016760  141.6180
# 3           FDX07        19.20                 2         0.000000  182.0950
# 4           NCD19         8.93                 1         0.000000   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2009            2                     3            3
# 2                       1999            2                     1            2
# 3                       1998            2                     3            1
# 4                       1987            1                     3            2
#
# ...

# %%
#Dropping the columns which haves all the unique variable
data = data.drop(columns='Item_Identifier')

# %%
data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0         9.30                 1         0.016047  249.8092
# 1         5.92                 2         0.019278   48.2692
# 2        17.50                 1         0.016760  141.6180
# 3        19.20                 2         0.000000  182.0950
# 4         8.93                 1         0.000000   53.8614
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2009            2                     3            3
# 2                       1999            2                     1            2
# 3                       1998            2                     3            1
# 4                       1987            1                     3            2
#
#    Item_Outlet_Sales  Item_Type_Baking Goods  ...  Outlet_Identifier_OUT010  \
# ...

# %% [markdown]
# ## **SCaling the Data**

# %%
#FInding the min and max of the columns to be scaled
item_weight_min = data['Item_Weight'].min()
item_weight_max = data['Item_Weight'].max()

item_mrp_min = data['Item_MRP'].min()
item_mrp_max = data['Item_MRP'].max()

item_outlet_sales_min = data['Item_Outlet_Sales'].min()
item_outlet_sales_max = data['Item_Outlet_Sales'].max()

# %%
#Printing the minimum and maximum
print('Minimun_Weight ',item_weight_min,' Maximum Weight ',item_weight_max)
print('Minimum Mrp ', item_mrp_min,' Maximum Mrp ',item_mrp_max)
print('Minimum Outlet sales ',item_outlet_sales_min, ' Maximum Sales', item_outlet_sales_max)
# Out:
# Minimun_Weight  4.555  Maximum Weight  21.35
# Minimum Mrp  31.29  Maximum Mrp  266.8884
# Minimum Outlet sales  33.29  Maximum Sales 13086.9648

# %%
# Min MAx Scaling
data['Item_Weight'] = (data['Item_Weight']-item_weight_min)/(item_weight_max-item_weight_min)
data['Item_MRP'] = (data['Item_MRP']-item_mrp_min)/(item_mrp_max-item_mrp_min)
data['Item_Outlet_Sales'] = (data['Item_Outlet_Sales']-item_outlet_sales_min)/(item_outlet_sales_max-item_outlet_sales_min)

# %%
data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0     0.282525                 1         0.016047  0.927507
# 1     0.081274                 2         0.019278  0.072068
# 2     0.770765                 1         0.016760  0.468288
# 3     0.871986                 2         0.000000  0.640093
# 4     0.260494                 1         0.000000  0.095805
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2009            2                     3            3
# 2                       1999            2                     1            2
# 3                       1998            2                     3            1
# 4                       1987            1                     3            2
#
#    Item_Outlet_Sales  Item_Type_Baking Goods  ...  Outlet_Identifier_OUT010  \
# ...

# %%
data.to_csv('Train_Cleaned.csv')
