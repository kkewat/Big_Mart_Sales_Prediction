# %% [markdown]
# <a href="https://colab.research.google.com/github/kkewat/Big_Mart_Sales_Prediction/blob/main/Big_Marts_Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Importing Libraries required for deep Learning models

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Importing the layers

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Importing the Dataset

# %%
Train_Data = pd.read_csv('Train_Cleaned.csv')
Test_Data = pd.read_csv('Test_Cleaned.csv')

# %%
#Viewing the data
Train_Data.head()
# Out:
#    Unnamed: 0  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           0     0.282525               1.0         0.016047  0.927507
# 1           1     0.081274               2.0         0.019278  0.072068
# 2           2     0.770765               1.0         0.016760  0.468288
# 3           3     0.871986               2.0         0.000000  0.640093
# 4           4     0.260494               1.0         0.000000  0.095805
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2009            2                     3            3
# 2                       1999            2                     1            2
# 3                       1998            2                     3            1
# 4                       1987            1                     3            2
#
# ...

# %%
Test_Data.head()
# Out:
#    Unnamed: 0  Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0           0     0.964275               1.0         0.007565  0.325012
# 1           1     0.222983               2.0         0.038428  0.237819
# 2           2     0.598095               1.0         0.099575  0.893316
# 3           3     0.164335               1.0         0.015388  0.525233
# 4           4     0.484706               2.0         0.118599  0.861381
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2007            2                     2            2
# 2                       1998            2                     3            1
# 3                       2007            2                     2            2
# 4                       1985            2                     3            4
#
#    Item_Type_Baking Goods  ...  Outlet_Identifier_OUT010  \
# ...

# %% [markdown]
# Dropping the first column since its not wanted

# %%
Train_Data = Train_Data.drop(Train_Data.columns[0], axis=1)

# %%
Train_Data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0     0.282525               1.0         0.016047  0.927507
# 1     0.081274               2.0         0.019278  0.072068
# 2     0.770765               1.0         0.016760  0.468288
# 3     0.871986               2.0         0.000000  0.640093
# 4     0.260494               1.0         0.000000  0.095805
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2009            2                     3            3
# 2                       1999            2                     1            2
# 3                       1998            2                     3            1
# 4                       1987            1                     3            2
#
#    Item_Outlet_Sales  Item_Type_Baking Goods  ...  Outlet_Identifier_OUT010  \
# ...

# %%
Test_Data = Test_Data.drop(Test_Data.columns[0], axis=1)

# %%
Test_Data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0     0.964275               1.0         0.007565  0.325012
# 1     0.222983               2.0         0.038428  0.237819
# 2     0.598095               1.0         0.099575  0.893316
# 3     0.164335               1.0         0.015388  0.525233
# 4     0.484706               2.0         0.118599  0.861381
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                       1999            2                     1            2
# 1                       2007            2                     2            2
# 2                       1998            2                     3            1
# 3                       2007            2                     2            2
# 4                       1985            2                     3            4
#
#    Item_Type_Baking Goods  Item_Type_Breads  ...  Outlet_Identifier_OUT010  \
# ...

# %% [markdown]
# Splitting the independent and Dependent Variables

# %%
X = Train_Data.drop('Item_Outlet_Sales',axis=1)
y = Train_Data['Item_Outlet_Sales']

# %% [markdown]
# Seeing the Shape of independent and dependent variables

# %%
X.shape, y.shape
# Out:
# ((8523, 34), (8523,))

# %% [markdown]
# Seperating Training and Validation

# %%
#Importing the libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#Seperating training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=50, test_size=0.2)
